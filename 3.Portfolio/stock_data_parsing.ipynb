# %% [markdown]
# ## 주식 데이터 파싱 (한국)
#
# - (1) 한국거래소에서 운영하는 기업공시채널 : https://kind.krx.co.kr/main.do?method=loadInitPage&scrnmode=1
#
# - (2) 마켓 데이터 취급하는 한국 거래소 사이트(본체) : https://km.krx.co.kr/main/main.jsp
#
# - 여기 2개의 사이트에서 현재 주식시장에 상장되어 있는 상장법인목록을 크롤링해보자
#
#     - 위 사이트에 방문에서 조건을 설정하고 csv나 excel로 다운받을 수도 있지만, 지난 주차에 배운 크롤링으로 한번 해본다
#
#     - (2)이 본체 ((2)이 (1)에 데이터를 제공)이다. (1) 사이트 크롤링과 (2) 사이트 크롤링을 모두 해본다.
#
#     - (1)이 훨씬 쉽지만, (2)에 주식 데이터 뿐만 아니라 활용할 수 있는 데이터가 많기 때문에 (2)도 다루게 되었다.

# %%
import pandas as pd

# %%
# (1) 사이트 크롤링
# 코스피, 코스닥으로 나눠서 상장법인의 종목코드를 구해본다. 
# 여기서 csv, excel을 다운받을 수 있다. http://kind.krx.co.kr/corpgeneral/corpList.do?method=loadInitPage

# 마켓 타입(market type)에 따라 download url이 다름. 딕셔너리 형태로 지정
stock_type = {
    'kospi': 'stockMkt',
    'kosdaq': 'kosdaqMkt'
}

# 코스피와 코스닥 download url 조합
def get_download_stock(market_type=None):

    # 딕셔너리를 통해 어떤 마켓타입인지 확인하고 market type 파라미터를 지정해준다. 
    market_type = stock_type[market_type]

    # 다운로드 할 때 개발자도구에서 다음 사이트를 요청하는 것을 확인한다.
    download_link = 'http://kind.krx.co.kr/corpgeneral/corpList.do?method=download'

    # 마켓 타입에 따라 파라미터를 다르게 넘겨줘서 원하는 마켓 목록만 다운받을 수 있다.
    download_link = download_link + '&marketType=' + market_type

    # 이렇게 저장하면 파일을 다운받아서 따로 pandas를 통해 열지 않고 바로 데이터프레임 형태로 저장할 수 있다.
    # 사이트가 다운로드할 내용을 html 구조로 제공해야 다음과 같이 read_html으로 받을 수 있다.
    df = pd.read_html(download_link, header=0)[0]
    return df


# kospi 종목코드 목록 다운로드
def get_download_kospi():

    # download url 함수 호출
    df = get_download_stock('kospi')

    # 오른쪽으로 6자리로 정렬하고 나머지는 0으로 채운다. (다운로드 받을 때 종목코드에 앞쪽 0이 사라짐)
    df.종목코드 = df.종목코드.map('{:06d}'.format)
    return df

# kosdaq 종목코드 목록 다운로드
def get_download_kosdaq():

    # download url 함수 호출
    df = get_download_stock('kosdaq')

    # 마찬가지
    df.종목코드 = df.종목코드.map('{:06d}'.format)
    return df

# kospi, kosdaq 종목코드 각각 다운로드
kospi_df = get_download_kospi()
기kosdaq_df = get_download_kosdaq()

# %%
# 코스피와 코스닥 5개씩 출력해보기
print(kospi_df.head(5))
print(kosdaq_df.head(5))

# 코스피와 코스닥 목록을 합친다.
code_df = pd.concat([kospi_df, kosdaq_df])

# 필요한 칼럼인 회사명, 종목코드만 가져온다.
list_df = code_df[['회사명', '종목코드']]

# 칼럼을 한글이 아닌 영어로 간단하게 바꾼다. '회사명' = name, 종목코드 = 'code'
list_df = list_df.rename(columns={'회사명': 'name', '종목코드': 'code'})
# Out:
# 회사명    종목코드             업종                주요제품         상장일  결산월   대표자명  \
# 0    JS전선  005560  절연선 및 케이블 제조업  선박선,고무선,전력선,통신선 제조  2007-11-12  12월    이익희
# 1   거북선2호  101380            NaN         운송장비(선박) 임대  2008-04-25  12월    신주선
# 2   거북선6호  114140            NaN                 NaN  2009-10-01  12월    김연신
# 3   교보메리츠  064900            NaN           부동산 투자,운용  2002-01-30  12월  김 상 진
# 4  국제관광공사  028780            NaN                 NaN  1966-03-18  12월    NaN
#
#                        홈페이지       지역
# 0  http://www.jscable.co.kr     충청남도
# 1                       NaN    부산광역시
# 2                       NaN  제주특별자치도
# 3                       NaN    서울특별시
# 4                       NaN      NaN
#          회사명    종목코드                   업종                         주요제품  \
# 0         3R  037730                  NaN               DVR(디지털영상저장장치)
# 1     3노드디지탈  900010  회사 본부 및 경영 컨설팅 서비스업                         지주회사
# 2  IBKS제7호스팩  276920           금융 지원 서비스업                       기업인수목적
# 3     KTB드림1  042300                  NaN       유가증권등의매매등을통한자산의투자·운용업무
# 4   KTB자산배분2  038380                  NaN  유가증권등의 매매등을 통한 자산의 투자, 운용업무
#
#           상장일  결산월  대표자명                                     홈페이지      지역
# 0  2000-07-25  12월   장성익                      http://WWW.3R.CO.KR   서울특별시
# 1  2007-08-17  12월  리유쯔슝  http://www.3nod.com.cn/index/index.aspx  케이맨 제도
# 2  2017-11-10  12월   문대우                                      NaN   서울특별시
# 3  2000-05-26  03월   장상기                                      NaN   서울특별시
# 4  2000-02-25  NaN   김형찬                                      NaN   서울특별시

# %%
# 특정 회사의 종목코드를 갖고와보자.

# 회사명으로 주식 종목 코드를 획득할 수 있도록 하는 함수
def get_code(df, name):

    #query로 name(회사명)이 파라미터로 넘겨준 name과 같으면 code열에서 종목코드 찾고 스트링으로 출력하는데 인덱스 번호 빼고 출력(false)
    code = df.query("name=='{}'".format(name))['code'].to_string(index=False)
    # 위와같이 code명을 가져오면 앞에 공백이 붙어있는 상황이 발생하여 앞뒤로 strip() 하여 공백 제거
    code = code.strip()
    return code


# 삼성전자의 종목코드를 갖고와보자.
code = get_code(list_df, '삼성전자')
print(code)
# Out:
# 005930

# %%
# (2) 사이트 크롤링
# 여기서 csv, excel을 다운받을 수 있다. http://marketdata.krx.co.kr/mdi#document=040601

from io import BytesIO 
from urllib.request import urlopen, Request
import pandas as pd
import pickle
# import sqlite3

# 파일을 다운로드하는 것을 클릭하면 다음 링크를 호출함. 
# 링크를 보면 OTP가 생성됨을 확인할 수 있고, 
# 다운로드할 내용의 여러 조건들이 파라미터로 지정됨을 알 수 있음. 개발자도구로 확인
# 마찬가지로 헤더도 같이 넘겨줘야함
req_url='http://marketdata.krx.co.kr/contents/COM/GenerateOTP.jspx?name=fileDown&filetype=xls&url=MKD/04/0406/04060100/mkd04060100_01&market_gubun=ALL&isu_cdnm=%EC%A0%84%EC%B2%B4&isu_cd=&isu_nm=&isu_srt_cd=&sort_type=A&std_ind_cd=&par_pr=&cpta_scl=&sttl_trm=&lst_stk_vl=1&in_lst_stk_vl=&in_lst_stk_vl2=&cpt=1&in_cpt=&in_cpt2=&isu_cdnm=%EC%A0%84%EC%B2%B4&isu_cd=&mktpartc_no=&isu_srt_cd=&pagePath=%2Fcontents%2FMKD%2F04%2F0406%2F04060100%2FMKD04060100.jsp'

headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'}

# requests 라이브러리를 사용하면, requests.get(url, headers=headers) 하면 되지만, 표준라이브러리 urllib 사용해봄
req1 = Request(req_url,headers=headers)
result = urlopen(req1)

# 최종적으로 암호화된 코드가 리턴되는데 바이트형태라 디코딩해줌
code = result.read().decode()

# 파일을 다운로드하는 링크에 otp로 암호화된 코드가 포함이 됨. 링크 url에 ?code= 에 코드 파라미터 값을 넘겨줌
req_url2 = 'http://file.krx.co.kr/download.jspx?code=' + code 


# 마찬가지로 다운로드 링크를 요청할 때 헤더를 넘겨줘야하는데 referer도 같이 넘겨줘야 한다.
headers = {'Referer': 'http://marketdata.krx.co.kr/mdi', 'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'} 

req2 = Request(req_url2, headers=headers) # 헤더(리퍼러) 추가 

# 바이트 스트림 형태의 데이터
byte_data = urlopen(req2).read()

# 여기는 html구조로 제공되는 것이 아니라 byte 형태로 excel 구조로 내용을 만들어줘서, read_excel로 읽어온다.
# byte_data는 BytesIO 객체로 바꿔서 인 메모리 바이트 스트림으로 바꾸고 read_excel로 읽어온다.
df = pd.read_excel(BytesIO(byte_data))

# 갯수만큼 숫자로 붙여진 인덱스는 삭제
del df['번호'] 

# 칼럼별로 타입지정과 전처리를 수행한다. 숫자를 나타내는 문자열에 , 가 있으면 지우고 수치형자료로 변환한다.
df['종목코드'] = df['종목코드'].map(lambda x: f'{x:0>6}') # 길이 6 오른쪽으로 정렬하고 남는 공간 0으로 채움.
df['업종코드'] = df['업종코드'].map(lambda x: f'{x:0>6}') 
df['상장주식수(주)'] = df['상장주식수(주)'].str.replace(",", "") 
df['상장주식수(주)'] = pd.to_numeric(df['상장주식수(주)'])  
df['자본금(원)'] = df['자본금(원)'].str.replace(",", "") 
df['자본금(원)'] = pd.to_numeric(df['자본금(원)'])

# %%
print(df.head(5))
# Out:
# 종목코드     기업명    업종코드               업종  상장주식수(주)       자본금(원) 액면가(원)  \
# 0  060310      3S  032902    특수 목적용 기계 제조업  44802511  22401255500    500
# 1  095570  AJ네트웍스  147603  산업용 기계 및 장비 임대업  46822295  46822295000  1,000
# 2  006840   AK홀딩스  116409           기타 금융업  13247561  66237805000  5,000
# 3  054620  APS홀딩스  116409           기타 금융업  20394221  10197110500    500
# 4  265520   AP시스템  032902    특수 목적용 기계 제조업  14480227   7240113500    500
#
#      통화구분          대표전화                              주소
# 0  원(KRW)   02-896-9474        서울특별시 금천구  시흥대로71길 30-1
# 1  원(KRW)  02-6363-9999    서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)
# 2  원(KRW)   02-768-2923            서울특별시 마포구 양화로 188 -
# 3  원(KRW)  031-776-1800  경기도 화성시 동탄면 동탄산단9길 23-12 (동탄면)
# 4  원(KRW)  031-379-2700  경기도 화성시  동탄면 동탄산단8길 15-5 &nbsp

# %%
# pickle 로 저장 (추천)
df.to_pickle('상장법인목록.pkl')

# pickle 읽어오기
df = pd.read_pickle('상장법인목록.pkl')

print(df.head(5))

# input_output.ipynb에서 다뤘던 것처럼, excel, csv, database등 다양한 형태로 자료를 관리할 수 있다.
# Out:
# 종목코드     기업명    업종코드               업종  상장주식수(주)       자본금(원) 액면가(원)  \
# 0  060310      3S  032902    특수 목적용 기계 제조업  44802511  22401255500    500
# 1  095570  AJ네트웍스  147603  산업용 기계 및 장비 임대업  46822295  46822295000  1,000
# 2  006840   AK홀딩스  116409           기타 금융업  13247561  66237805000  5,000
# 3  054620  APS홀딩스  116409           기타 금융업  20394221  10197110500    500
# 4  265520   AP시스템  032902    특수 목적용 기계 제조업  14480227   7240113500    500
#
#      통화구분          대표전화                              주소
# 0  원(KRW)   02-896-9474        서울특별시 금천구  시흥대로71길 30-1
# 1  원(KRW)  02-6363-9999    서울특별시 송파구 정의로8길 9 (문정동,AJ빌딩)
# 2  원(KRW)   02-768-2923            서울특별시 마포구 양화로 188 -
# 3  원(KRW)  031-776-1800  경기도 화성시 동탄면 동탄산단9길 23-12 (동탄면)
# 4  원(KRW)  031-379-2700  경기도 화성시  동탄면 동탄산단8길 15-5 &nbsp

# %% [markdown]
# ## 상장법인목록을 이용해서 종목의 주가 데이터 가져오기 (네이버)
#
# - 네이버 과거 주가는 수정주가로 반영되어 있지 않고, 페이지를 돌면서 크롤링 해야 하므로 비효율적
#
# - 네이버 금융에서 제공하는 차트는 수정주가로 반영되어 있는데, 이것을 가져올 수 있지 않을까?
#
#     - 다만 확인해본 결과 정확한 데이터는 아니므로 투자에 참고하기에는 꺼림칙하다.
#
#     - xml 데이터 구조이다. 파이썬에서는 서드파티 라이브러리로 lxml을 제공하는데 xml는 beautifulsoup과 lxml 이용해서 처리할 수도 있지만 여기서는 표준 xml 패키지를 사용해보겠다.
#
#     - xml 이란 ? : https://ko.wikipedia.org/wiki/XML

# %%
import pandas
from urllib.request import urlopen 
# XML을 객체화 하기 위해서는 xml.etree.ElementTree이 필요하므로 import 합니다.
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup
import datetime


# 네이버 차트 수정주가 가져오기. 앞에서 구한 특정 종목의 종목코드를 가져온다.
code = get_code(list_df, '삼성전자')
count = '6000' 
day = 'day'

# 이건 차트 띄울때 개발자 도구 확인하면 사이트 확인할 수 있다.
url = f'https://fchart.stock.naver.com/sise.nhn?symbol={code}&timeframe={day}&count={count}&requestType=0' 

# 요청
r = urlopen(url) 

# 인코딩 해야지 정확한 데이터가 안깨지고 가져와진다. 해당 사이트 인코딩은 EUC-KR
xml_data = r.read().decode('EUC-KR') 

# beautiful soup 이용해서 xml 데이터 정적 크롤링을 수행할 수도 있다. 
# # beautifulsoup으로 가져오기
# xml_data = requests.get(url)
# soup_xml = BeautifulSoup(xml_data.text, 'lxml')
# for i, row in enumerate(soup_xml.find_all('item')):
#   price = row['data'].split('|')
# 
# 하지만 xml데이터를 다루는 다른 방법도 하나 알아보자.

# XML객체로 파싱(Parse)하기
# XML로 파싱하는 방법은 두 가지가 있습니다.
    # 1. xml 파일형태로 존재하는 경우
    # 2. xml 문자열 형태로 존재하는 경우

# 우리는 2 문자열 형태로 존재하는 경우이다. 
# 문자열 값으로 존재하는 경우 fromstring() 메서드에 xml 데이터 문자열을 넘깁니다.

root = ET.fromstring(xml_data)

# xml 데이터를 객체로 파싱한 이후 트리 안에서 각각의 태그를 검색할 수 있다. 
# 태그 검색 : find, findall
print(root.findall('.//item'))
# Out:
# [<Element 'item' at 0x000002238A939E58>, <Element 'item' at 0x000002238A939EF8>, <Element 'item' at 0x000002238A939D18>, <Element 'item' at 0x000002238A9394F8>, <Element 'item' at 0x000002238A939B38>, <Element 'item' at 0x000002238A939638>, <Element 'item' at 0x000002238A939EA8>, <Element 'item' at 0x000002238A939BD8>, <Element 'item' at 0x000002238A939CC8>, <Element 'item' at 0x000002238A939D68>, <Element 'item' at 0x000002238A939318>, <Element 'item' at 0x000002238A939E08>, <Element 'item' at 0x000002238A939C78>, <Element 'item' at 0x000002238A939DB8>, <Element 'item' at 0x000002238A9399A8>, <Element 'item' at 0x000002238A939908>, <Element 'item' at 0x000002238A939138>, <Element 'item' at 0x000002238A939A98>, <Element 'item' at 0x000002238A9390E8>, <Element 'item' at 0x000002238A939278>, <Element 'item' at 0x000002238A939868>, <Element 'item' at 0x000002238A939F98>, <Element 'item' at 0x000002238A939818>, <Element 'item' at 0x00000223880BAEF8>, <Element 'item' at 0x00000223880BA548>, <Element 'item' at 0x00000223880BAF48>, <Element 'item' at 0x00000223880BAAE8>, <Element 'item' at 0x00000223880BACC8>, <Element 'item' at 0x00000223880BAC28>, <Element 'item' at 0x00000223880BAC78>, <Element 'item' at 0x00000223880BAD18>, <Element 'item' at 0x00000223880BAD68>, <Element 'item' at 0x00000223880BAEA8>, <Element 'item' at 0x00000223880BA048>, <Element 'item' at 0x00000223880BA458>, <Element 'item' at 0x00000223880BAF98>, <Element 'item' at 0x00000223880BAE58>, <Element 'item' at 0x00000223880BA9A8>, <Element 'item' at 0x00000223880BAB38>, <Element 'item' at 0x00000223880BAB88>, <Element 'item' at 0x00000223880BA868>, <Element 'item' at 0x00000223880BA728>, <Element 'item' at 0x00000223880BA3B8>, <Element 'item' at 0x00000223880BA228>, <Element 'item' at 0x00000223880BA908>, <Element 'item' at 0x00000223880BA5E8>, <Element 'item' at 0x00000223880BA408>, <Element 'item' at 0x00000223880BA7C8>, <Element 'item' at 0x00000223880BA6D8>, <Element 'item' at 0x00000223880BA818>, <Element 'item' at 0x00000223880BA318>, <Element 'item' at 0x00000223880BA4A8>, <Element 'item' at 0x00000223880BA368>, <Element 'item' at 0x00000223880BA138>, <Element 'item' at 0x00000223880BA638>, <Element 'item' at 0x00000223880BA278>, <Element 'item' at 0x0000022387D24EA8>, <Element 'item' at 0x0000022387D24C28>, <Element 'item' at 0x0000022387D24F48>, <Element 'item' at 0x0000022387D24048>, <Element 'item' at 0x0000022387D24098>, <Element 'item' at 0x0000022387D24318>, <Element 'item' at 0x0000022387D24D18>, <Element 'item' at 0x0000022387D24C78>, <Element 'item' at 0x0000022387D24B38>, <Element 'item' at 0x0000022387D24E58>, <Element 'item' at 0x0000022387D24458>, <Element 'item' at 0x0000022387D246D8>, <Element 'item' at 0x0000022387D245E8>, <Element 'item' at 0x0000022387D24CC8>, <Element 'item' at 0x0000022387D241D8>, <Element 'item' at 0x0000022387D24408>, <Element 'item' at 0x0000022387D24188>, <Element 'item' at 0x0000022387D243B8>, <Element 'item' at 0x0000022389C80868>, <Element 'item' at 0x0000022389C808B8>, <Element 'item' at 0x0000022389C80818>, <Element 'item' at 0x0000022389C809F8>, <Element 'item' at 0x0000022387C9FCC8>, <Element 'item' at 0x0000022387C9FD68>, <Element 'item' at 0x0000022387C9FF98>, <Element 'item' at 0x0000022387C9F4A8>, <Element 'item' at 0x0000022387C9F868>, <Element 'item' at 0x0000022387C9F908>, <Element 'item' at 0x0000022387C9F9F8>, <Element 'item' at 0x0000022387C9FA48>, <Element 'item' at 0x0000022387C9FAE8>, <Element 'item' at 0x0000022387C9F638>, <Element 'item' at 0x0000022387C9FB88>, <Element 'item' at 0x0000022387C9FC28>, <Element 'item' at 0x0000022387C9F5E8>, <Element 'item' at 0x0000022387C9FE08>, <Element 'item' at 0x0000022387C9FE58>, <Element 'item' at 0x0000022387C9FEA8>, <Element 'item' at 0x0000022387C9FEF8>, <Element 'item' at 0x0000022388518B88>, <Element 'item' at 0x0000022388518DB8>, <Element 'item' at 0x0000022388518C78>, <Element 'item' at 0x0000022388518778>, <Element 'item' at 0x0000022388518408>, ...

# %%
price_table=[]

# 태그별로 반복문
for i, row in enumerate(root.findall('.//item')):
    
    # 태그의 속성을 이용해서 안에 있는 데이터를 가져온다. 구분자는 | 로 되어있음을 확인한다.
    price = row.attrib['data'].split('|')
    # price = [19900113, 44000, 45800, ...]

    # 2000 이후 데이터만 가져오자
    # 문자열 데이터는 적절하게 변환시켜서 저장한다.
    if price[0] >= "20000101":  
        price[0] = datetime.datetime.strptime(price[0],'%Y%m%d')
        price[1] = int(price[1]) 
        price[2] = int(price[2]) 
        price[3] = int(price[3]) 
        price[4] = int(price[4]) 
        price[5] = int(price[5]) 
        price_table.append(price)

# 데이터프레임으로 저장
price_df=pd.DataFrame(price_table)
price_headers=['Date', 'Open','High','Low','Close', 'Volume']
price_df.columns=price_headers
price_df.set_index('Date',inplace=True)

print(price_df.head(10))
# Out:
# Open  High   Low  Close   Volume
# Date
# 2000-01-04  6000  6110  5660   6110  1483967
# 2000-01-05  5800  6060  5520   5580  1493604
# 2000-01-06  5750  5780  5580   5620  1087810
# 2000-01-07  5560  5670  5360   5540   806195
# 2000-01-10  5600  5770  5580   5770   937615
# 2000-01-11  5820  6100  5770   5770  1194974
# 2000-01-12  5610  5740  5600   5720   584492
# 2000-01-13  5600  5740  5560   5710   823830
# 2000-01-14  5720  5880  5680   5830   987576
# 2000-01-17  6000  6180  5920   6100  1270138

# %% [markdown]
# ## 네이버 금융의 자료들을 이용하는 방법
#
# - 앞서 네이버 일별 주가, 차트 데이터도 파싱이 가능함을 확인했다.
#
# - 이번에는 네이버 금융에서 데이터를 제공하고 관리하는 방식인 api를 이용해서 갖고오는 방법을 알아보자
#
#     - 여기서는 etf목록을 가져올텐데 다른 데이터에도 사용할 수 있는 방법이다. 사이트 : https://finance.naver.com/sise/etf.nhn
#
#     - 위 사이트에서 개발자도구를 열고 ctrl + f를 해서 ajax를 검색한다.
#
#     - 그러면 /*Ajax 호출을 통한 ETF 리스트 테이블 업데이트*/ 부분이 나오고 여기에서 사이트의 api 주소가 무엇인지 유추할 수 있다.
#
# - 네이버 금융 api는 json 형식의 데이터를 사용한다.
#
#     - JSON은 JavaScript Object Notation의 약자로서 JavaScript 문법에 영향을 받아 개발된 Lightweight한 데이타 표현 방식이다.
#
#     - JSON은 데이타를 교환하는 한 포맷으로서 그 단순함과 유연함 때문에 널리 사용되고 있다.
#
#     - 특히 웹 브라우져와 웹서버 사이에 데이타를 교환하는데 많이 사용되고 있다. 가장 많이 사용되는 JSON 포맷은 Key-Value Pair의 컬렉션이다.
#
#     - Python은 기본적으로 JSON 표준 라이브러리(json)를 제공하고 있는데, "import json" 을 사용하여 JSON 라이브러리를 사용할 수 있다
#
#     - JSON 라이브러리를 사용하면, Python 타입의 Object를 JSON 문자열로 변경할 수 있으며 (JSON 인코딩 : json.dump() 메서드 사용)
#
#     - 또한 JSON 문자열을 다시 Python 타입으로 변환할 수 있다 (JSON 디코딩 : json.loads() 메서드 사용).

# %%
# 유추한 url은 다음과 같다.

url = 'https://finance.naver.com/api/sise/etfItemList.nhn' 

# 확인해보면 네이버 금융 api는 json 형태를 통해 데이터를 관리하고 있음을 알 수 있다.

#{"resultCode":"success","result":{"etfItemList":[{"itemcode":"069500","etfTabCode":1,"itemname":"KODEX 200","nowVal":29465,"risefall":"5","changeVal":-315,"changeRate":-1.06,"nav":29522.0,"threeMonthEarnRate":8.841,"quant":3542631,"amonut":104730,"marketSum":92063}, ...


import json 
from urllib.request import urlopen
import requests
from pandas.io.json import json_normalize

# 웹 요청을 하고 사이트 인코딩(CP949)에 맞게 디코딩해준다. 
raw_data = urlopen(url).read().decode('CP949') 

# json데이터를 파이썬에서 사용할 수 있게 디코딩 해준다. json.loads()메서드 사용
json_data = json.loads(raw_data)

# json문자열 데이터가 파이썬에서 활용할 수 있는 딕셔너리 형태로 변환이 된다.
print(json_data)
# Out:
# {'resultCode': 'success', 'result': {'etfItemList': [{'itemcode': '069500', 'etfTabCode': 1, 'itemname': 'KODEX 200', 'nowVal': 31325, 'risefall': '5', 'changeVal': -390, 'changeRate': -1.23, 'nav': 31424.0, 'threeMonthEarnRate': 9.2791, 'quant': 5170204, 'amonut': 162520, 'marketSum': 50167}, {'itemcode': '102110', 'etfTabCode': 1, 'itemname': 'TIGER 200', 'nowVal': 31340, 'risefall': '5', 'changeVal': -380, 'changeRate': -1.2, 'nav': 31424.0, 'threeMonthEarnRate': 9.3529, 'quant': 766875, 'amonut': 24093, 'marketSum': 26388}, {'itemcode': '252670', 'etfTabCode': 3, 'itemname': 'KODEX 200선물인버스2X', 'nowVal': 4140, 'risefall': '2', 'changeVal': 90, 'changeRate': 2.22, 'nav': 4173.0, 'threeMonthEarnRate': -20.1971, 'quant': 149233144, 'amonut': 616480, 'marketSum': 23896}, {'itemcode': '122630', 'etfTabCode': 3, 'itemname': 'KODEX 레버리지', 'nowVal': 15020, 'risefall': '5', 'changeVal': -345, 'changeRate': -2.25, 'nav': 15043.0, 'threeMonthEarnRate': 17.0666, 'quant': 40227032, 'amonut': 606777, 'marketSum': 22740}, {'itemcode': '153130', 'etfTabCode': 6, 'itemname': 'KODEX 단기채권', 'nowVal': 102455, 'risefall': '5', 'changeVal': -5, 'changeRate': 0.0, 'nav': 102459.0, 'threeMonthEarnRate': 0.0976, 'quant': 11487, 'amonut': 1176, 'marketSum': 17611}, {'itemcode': '273130', 'etfTabCode': 6, 'itemname': 'KODEX 종합채권(AA-이상)액티브', 'nowVal': 110395, 'risefall': '2', 'changeVal': 220, 'changeRate': 0.2, 'nav': 110358.0, 'threeMonthEarnRate': 0.0817, 'quant': 5061, 'amonut': 558, 'marketSum': 13435}, {'itemcode': '102780', 'etfTabCode': 2, 'itemname': 'KODEX 삼성그룹', 'nowVal': 7650, 'risefall': '5', 'changeVal': -85, 'changeRate': -1.1, 'nav': 7680.0, 'threeMonthEarnRate': 6.0315, 'quant': 155009, 'amonut': 1185, 'marketSum': 13051}, {'itemcode': '157450', 'etfTabCode': 6, 'itemname': 'TIGER 단기통안채', 'nowVal': 100655, 'risefall': '3', 'changeVal': 0, 'changeRate': 0.0, 'nav': 100654.0, 'threeMonthEarnRate': 0.0994, 'quant': 980, 'amonut': 98, 'marketSum': 12028}, {'itemcode': '114800', 'etfTabCode': 3, 'itemname': 'KODEX 인버스', 'nowVal': 5445, 'risefall': '2', 'changeVal': 60, 'changeRate': 1.11, 'nav': 5466.0, 'threeMonthEarnRate': -10.1752, 'quant': 32076381, 'amonut': 174504, 'marketSum': 11941}, {'itemcode': '278530', 'etfTabCode': 1, 'itemname': 'KODEX 200TR', 'nowVal': 10050, 'risefall': '5', 'changeVal': -110, 'changeRate': -1.08, 'nav': 10072.0, 'threeMonthEarnRate': 9.2473, 'quant': 56613, 'amonut': 570, 'marketSum': 11578}, {'itemcode': '233740', 'etfTabCode': 1, 'itemname': 'KODEX 코스닥150 레버리지', 'nowVal': 13680, 'risefall': '5', 'changeVal': -470, 'changeRate': -3.32, 'nav': 13746.0, 'threeMonthEarnRate': 35.0835, 'quant': 15925398, 'amonut': 220914, 'marketSum': 9932}, {'itemcode': '148020', 'etfTabCode': 1, 'itemname': 'KBSTAR 200', 'nowVal': 31380, 'risefall': '5', 'changeVal': -375, 'changeRate': -1.18, 'nav': 31465.0, 'threeMonthEarnRate': 9.3793, 'quant': 270543, 'amonut': 8520, 'marketSum': 9885}, {'itemcode': '214980', 'etfTabCode': 6, 'itemname': 'KODEX 단기채권PLUS', 'nowVal': 102675, 'risefall': '3', 'changeVal': 0, 'changeRate': 0.0, 'nav': 102682.0, 'threeMonthEarnRate': 0.1414, 'quant': 2029, 'amonut': 208, 'marketSum': 8266}, {'itemcode': '152100', 'etfTabCode': 1, 'itemname': 'ARIRANG 200', 'nowVal': 31495, 'risefall': '5', 'changeVal': -400, 'changeRate': -1.25, 'nav': 31593.0, 'threeMonthEarnRate': 9.3905, 'quant': 118863, 'amonut': 3752, 'marketSum': 7181}, {'itemcode': '293180', 'etfTabCode': 1, 'itemname': 'HANARO 200', 'nowVal': 31355, 'risefall': '5', 'changeVal': -385, 'changeRate': -1.21, 'nav': 31441.0, 'threeMonthEarnRate': 9.3088, 'quant': 127931, 'amonut': 4025, 'marketSum': 7118}, {'itemcode': '105190', 'etfTabCode': 1, 'itemname': 'KINDEX 200', 'nowVal': 31385, 'risefall': '5', 'changeVal': -375, 'changeRate': -1.18, 'nav': 31475.0, 'threeMonthEarnRate': 9.2159, 'quant': 362104, 'amonut': 11407, 'marketSum': 7015}, {'itemcode': '272580', 'etfTabCode': 6, 'itemname': 'TIGER 단기채권액티브', 'nowVal': 50455, 'risefall' ...

# %%
# 딕셔너리 데이터 확인

# etf 코드와 이름만 반복문으로 출력해본다.
for each in json_data['result']['etfItemList']:
    print(each['itemcode'], each['itemname'])
# Out:
# 069500 KODEX 200
# 102110 TIGER 200
# 252670 KODEX 200선물인버스2X
# 122630 KODEX 레버리지
# 153130 KODEX 단기채권
# 273130 KODEX 종합채권(AA-이상)액티브
# 102780 KODEX 삼성그룹
# 157450 TIGER 단기통안채
# 114800 KODEX 인버스
# 278530 KODEX 200TR
# 233740 KODEX 코스닥150 레버리지
# 148020 KBSTAR 200
# 214980 KODEX 단기채권PLUS
# 152100 ARIRANG 200
# 293180 HANARO 200
# 105190 KINDEX 200
# 272580 TIGER 단기채권액티브
# 278540 KODEX MSCI Korea TR
# 069660 KOSEF 200
# 292150 TIGER TOP10
# 310970 TIGER MSCI Korea TR
# 261220 KODEX WTI원유선물(H)
# 251340 KODEX 코스닥150선물인버스
# 357870 TIGER CD금리투자KIS(합성)
# 226490 KODEX 코스피
# 305720 KODEX 2차전지산업
# 251350 KODEX 선진국MSCI World
# 133690 TIGER 미국나스닥100
# 190620 KINDEX 단기통안채
# 229200 KODEX 코스닥 150
# 305540 TIGER 2차전지테마
# 315930 KODEX Top5PlusTR
# 294400 KOSEF 200TR
# 306540 HANARO 단기통안채
# 295040 SMART 200TR
# 232080 TIGER 코스닥150
# 192090 TIGER 차이나CSI300
# 302450 KBSTAR 코스피
# 139260 TIGER 200 IT
# 204480 TIGER 차이나CSI300레버리지(합성)
# 132030 KODEX 골드선물(H)
# 148070 KOSEF 국고채10년
# 161510 ARIRANG 고배당주
# 332500 KINDEX 200TR
# 332940 HANARO MSCI Korea TR
# 278240 KBSTAR 코스닥150선물레버리지
# 314250 KODEX 미국FANG플러스(H)
# 245710 KINDEX 베트남VN30(합성)
# 168580 KINDEX 중국본토CSI300
# 270810 KBSTAR 코스닥150
# 144600 KODEX 은선물(H)
# 196230 KBSTAR 단기통안채
# 275980 TIGER 글로벌4차산업혁신기술(합성 H)
# 332930 HANARO 200TR
# 150460 TIGER 중국소비테마
# 130680 TIGER 원유선물Enhanced(H)
# 325020 KODEX 배당가치
# 139280 TIGER 경기방어
# 143860 TIGER 헬스케어
# 252710 TIGER 200선물인버스2X
# 143850 TIGER 미국S&P500선물(H)
# 267770 TIGER 200선물레버리지
# 273140 KODEX 단기변동금리부채권액티브
# 328370 ARIRANG 코스피TR
# 233160 TIGER 코스닥150 레버리지
# 091170 KODEX 은행
# 315960 KBSTAR 대형고배당10TR
# 325010 KODEX Fn성장
# 277630 TIGER 코스피
# 292190 KODEX KRX300
# 225040 TIGER 미국S&P500레버리지(합성 H)
# 219480 KODEX 미국S&P500선물(H)
# 108450 KINDEX 삼성그룹섹터가중
# 302190 TIGER 중장기국채
# 195930 TIGER 유로스탁스50(합성 H)
# 157490 TIGER 소프트웨어
# 272560 KBSTAR 단기국공채액티브
# 123310 TIGER 인버스
# 114260 KODEX 국고채3년
# 156080 KODEX MSCI Korea
# 245360 TIGER 차이나HSCEI
# 256750 KODEX 심천ChiNext(합성)
# 336160 KBSTAR 금융채액티브
# 270800 KBSTAR KQ고배당
# 091180 KODEX 자동차
# 329200 TIGER 부동산인프라고배당
# 122260 KOSEF 통안채1년
# 292500 SMART KRX300
# 285000 KBSTAR 200IT
# 182480 TIGER 미국MSCI리츠(합성 H)
# 102970 KODEX 증권
# 359210 KODEX 코스피TR
# 195980 ARIRANG 신흥국MSCI(합성 H)
# 219390 KBSTAR 미국S&P원유생산기업(합성 H)
# 361580 KBSTAR 200TR
# 136340 KBSTAR 중기우량회사채
# 337140 KODEX 코스피대형주
# 283580 KODEX 중국본토CSI300
# 266360 KODEX 미디어&엔터테인먼트
# 305080 TIGER 미국채10년선물
# 114820 TIGER 국채3년
# 130730 KOSEF 단기자금
# 252400 KBSTAR 200선물레버리지
# 261240 KODEX 미국달러선물
# 292050 KBSTAR KRX300
# 304770 HANARO 코스닥150
# 091160 KODEX 반도체
# 227830 ARIRANG 코스피
# 252420 KBSTAR 200선물인버스2X
# 304940 KODEX 미국나스닥100선물(H)
# 114100 KBSTAR 국고채3년
# 278620 ARIRANG 단기채권액티브
# 316670 KOSEF 코스닥150
# 245340 TIGER 미국다우존스30
# 122090 ARIRANG 코스피50
# 137610 TIGER 농산물선물Enhanced(H)
# 356540 KINDEX KIS종합채권(AA-이상)액티브
# 169950 KODEX 중국본토 A50
# 279530 KODEX 고배당
# 114470 KOSEF 국고채3년
# 304780 HANARO 200선물레버리지
# 217780 TIGER 차이나CSI300인버스(합성)
# 250780 TIGER 코스닥150선물인버스
# 099140 KODEX China H
# 282000 KBSTAR 국고채3년선물인버스
# 223190 KODEX 200가치저변동
# 272570 KBSTAR 중장기국공채액티브
# 091230 TIGER 반도체
# 333960 ARIRANG KS모멘텀가중TR
# 329750 TIGER 미국달러단기채권액티브
# 266370 KODEX IT
# 322400 HANARO e커머스
# 360200 KINDEX 미국S&P500
# 204450 KODEX China H 레버리지(H)
# 225130 KINDEX 골드선물 레버리지(합성 H)
# 243880 TIGER 200IT레버리지
# 269540 ARIRANG 미국S&P500(H)
# 253250 KOSEF 200선물레버리지
# 123320 TIGER 레버리지
# 139270 TIGER 200 금융
# 292160 TIGER KRX300
# 310960 TIGER 200TR
# 337150 KODEX 200exTOP
# 138230 KOSEF 미국달러선물
# 332620 ARIRANG 미국장기우량회사채
# 333980 ARIRANG KS퀄리티가중TR
# 276970 KODEX 미국S&P고배당커버드콜(합성 H)
# 272910 KINDEX 중장기국공채액티브
# 203780 TIGER 미국나스닥바이오
# 333940 ARIRANG KS로우볼가중TR
# 354500 KINDEX 코스닥150
# 227540 TIGER 200 헬스케어
# 261250 KODEX 미국달러선물레버리지
# 152870 파워 200
# 200250 KOSEF 인도Nifty50(합성)
# 211900 KODEX 배당성장
# 228810 TIGER 미디어컨텐츠
# 289040 KODEX MSCI KOREA ESG유니버설
# 152380 KODEX 국채선물10년
# 174360 KBSTAR 중국본토대형주CSI100
# 304660 KODEX 미국채울트라30년선물(H)
# 332610 ARIRANG 미국단기우량회사채
# 276650 KBSTAR 글로벌4차산업IT(합성 H)
# 306520 HANARO 200선물인버스
# 266410 KODEX 필수소비재
# 360750 TIGER 미국S&P500
# 236350 TIGER 인도니프티50레버리지(합성)
# 329650 KODEX TRF3070
# 108590 TREX 200
# 219900 KINDEX 중국본토CSI300레버리지(합성)
# 341850 TIGER KIS부동산인프라채권TR
# 176950 KODEX 국채선물10년인버스
# 326240 KBSTAR IT플러스
# 253160 ARIRANG 200선물인버스2X
# 295000 KBSTAR 국채선물10년
# 225800 KOSEF 미국달러선물레버리지
# 137930 마이다스 200커버드콜5%OTM
# 230480 KOSEF 미국달러선물인버스2X
# 237370 KODEX 배당성장채권혼합
# 333970 ARIRANG KS밸류가중TR
# 331910 KOSEF Fn중소형
# 251590 ARIRANG 고배당저변동50
# 114460 KINDEX 중기국고채
# 195920 TIGER 일본TOPIX(합성 H)
# 244580 KODEX 바이오
# 261120 TIGER 미국달러선물인버스2X
# 292730 FOCUS KRX300
# 152500 KINDEX 레버리지
# 117700 KODEX 건설
# 279540 KODEX 최소변동성
# 229720 KODEX KTOP30
# 315270 TIGER 200커뮤니케이션서비스
# 319640 TIGER 골드선물(H)
# 277650 TIGER 코스피중형주
# 244620 KODEX 모멘텀Plus
# 281990 KBSTAR 중소형고배당
# 322410 HANARO 고배당
# 292750 ARIRANG KRX300
# 285690 FOCUS ESG리더스
# 139250 TIGER 200 에너지화학
# 256440 KINDEX 인도네시아MSCI(합성)
# 300640 KBSTAR 게임테마
# 360150 KODEX 코스닥150롱코스피200숏선물
# 284430 KODEX 200미국채혼합
# 305050 KINDEX 코스피
# 304760 HANARO KRX300
# 248270 TIGER S&P글로벌헬스케어(합성)
# 261060 TIGER 코스닥150IT
# 182490 TIGER 단기선진하이일드(합성 H)
# 138540 TIGER 현대차그룹+펀더멘털
# 337120 KODEX Fn멀티팩터
# 360140 KODEX 200롱코스닥150숏선물
# 208470 SMART 선진국MSCI World(합성 H)
# 309230 KINDEX 미국WideMoat가치주
# 185680 KODEX 미국S&P바이오(합성)
# 183700 KBSTAR 채권혼합
# 252730 KBSTAR 모멘텀로우볼
# 277640 TIGER 코스피대형주
# 287180 ARIRANG 미국나스닥기술주
# 152280 KOSEF 200 선물
# 277540 KINDEX S&P아시아TOP50
# 306950 KODEX KRX300레버리지
# 237350 KODEX 코스피100
# 225050 TIGER 유로스탁스레버리지(합성 H)
# 280320 KINDEX 미국4차산업인터넷(합성 H)
# 316300 KINDEX 싱가포르리츠
# 248260 TIGER 일본TOPIX헬스케어(합성)
# 291630 KOSEF 코스닥150선물레버리지
# 140950 파워 코스피100
# 167860 KOSEF 국고채10년레버리지
# 333950 ARIRANG KS로우사이즈가중TR
# 266420 KODEX 헬스케어
# 218420 KODEX 미국S&P에너지(합성)
# 272220 KINDEX 스마트모멘텀
# 228790 TIGER 화장품
# 225030 TIGER 미국S&P500선물인버스(H)
# 210780 TIGER 코스피고배당
# 271060 KODEX 3대농산물선물(H)
# 266160 KBSTAR 고배당
# 289480 TIGER 200커버드콜ATM
# 205720 KINDEX 일본TOPIX인버스(합성 H)
# 261070 TIGER 코스닥150바이오테크
# 168300 KTOP 코스피50
# 276990 KODEX 글로벌4차산업로보틱스(합성)
# 307510 TIGER 의료기기
# 104520 KOSEF 블루칩
# 228820 TIGER KTOP30
# 280920 ARIRANG 주도업종
# 308620 KODEX 미국채10년선물
# 329670 KODEX TRF7030
# 276000 TIGER 글로벌자원생산기업(합성 H)
# 300950 KODEX 게임산업
# 329660 KODEX TRF5050
# 237440 TIGER 경기방어채권혼합
# 239660 ARIRANG 우량회사채50 1년
# 253150 ARIRANG 200선물레버리지
# 310080 KBSTAR 중국MSCI China선물(H)
# 251600 ARIRANG 고배당주채권혼합
# 241180 TIGER 일본니케이225
# 269420 KODEX S&P글로벌인프라(합성)
# 153270 KOSEF 코스피100
# 275290 KODEX MSCI밸류
# 280930 KODEX 미국러셀2000(H)
# 342140 KINDEX 모닝스타싱가포르리츠채권혼합
# 253290 KBSTAR 헬스케어채권혼합
# 143460 KINDEX 밸류대형
# 266550 ARIRANG 중형주저변동50
# 227570 TIGER 우량가치
# 159800 마이티 코스피100
# 346000 HANARO KAP초장기국고채
# 265690 KINDEX 러시아MSCI(합성)
# 220130 SMART 중국본토 중소형 CSI500(합성 H)
# 100910 KOSEF KRX100
# 245350 TIGER 유로스탁스배당30
# 322130 KINDEX 스마트로우볼
# 139230 TIGER 200 중공업
# 160580 TIGER 구리실물
# 174350 TIGER 로우볼
# 260200 KOSEF 배당바이백Plus
# 261260 KODEX 미국달러선물인버스2X
# 183710 KBSTAR 주식혼합
# 238720 KINDEX 일본Nikkei225(H)
# 250730 KBSTAR 차이나HSCEI(H)
# 104530 KOSEF 고배당
# 117460 KODEX 에너지화학
# 292560 TIGER 일본엔선물
# 319870 KBSTAR KRX300미국달러선물혼합
# 292130 TIGER 중소형성장
# 138520 TIGER 삼성그룹펀더멘털
# 352560 KODEX 다우존스미국리츠(H)
# 139660 KOSEF 미국달러선물인버스
# 243890 TIGER 200에너지화학레버리지
# 298770 KODEX 한국대만IT프리미어
# 200030 KODEX 미국S&P산업재(합성)
# 337160 KODEX 200ESG
# 307010 KBSTAR KRX300레버리지
# 101280 KODEX 일본TOPIX100
# 139320 TIGER 금은선물(H)
# 352540 KODEX TSE일본리츠(H)
# 234310 KBSTAR V&S셀렉트밸류
# 261110 TIGER 미국달러선물레버리지
# 253230 KOSEF 200선물인버스2X
# 131890 KINDEX 삼성그룹동일가중
# 354240 KBSTAR 미국고정배당우선증권ICE TR
# 292570 TIGER 일본엔선물레버리지
# 334690 KBSTAR 팔라듐선물(H)
# 271050 KODEX WTI원유선물인버스(H)
# 302170 TIGER 국채선물3년인버스
# 361590 KBSTAR 코스피ex200
# 302200 TIGER 중장기국채선물인버스
# 147970 TIGER 모멘텀
# 289670 ARIRANG 국채선물10년
# 215620 흥국 S&P코리아로우볼
# 267490 KBSTAR 미국장기국채선물레버리지(합성 H)
# 322150 KINDEX 스마트하이베타
# 251890 KINDEX 코스닥(합성)
# 302180 TIGER 국채선물10년인버스
# 252650 KODEX 200동일가중
# 145850 TREX 펀더멘탈 200
# 138910 KODEX 구리선물(H)
# 138920 KODEX 콩선물(H)
# 181480 KINDEX 미국다우존스리츠(합성 H)
# 138530 TIGER LG그룹+펀더멘털
# 105780 KBSTAR 5대그룹주
# 225060 TIGER 이머징마켓MSCI레버리지(합성 H)
# 211560 TIGER 배당성장
# 196030 KINDEX 일본TOPIX레버리지(H)
# 117690 TIGER 차이나항셍25
# 292340 마이티 200커버드콜ATM레버리지
# 157500 TIGER 증권
# 189400 ARIRANG 글로벌MSCI(합성 H)
# 217790 TIGER 가격조정
# 105010 TIGER 라틴35
# 140700 KODEX 보험
# 298340 ARIRANG 국채선물3년
# 296710 KODEX FnKorea50
# 309210 ARIRANG KRX300헬스케어
# 272230 KINDEX 스마트밸류
# 117680 KODEX 철강
# 292100 TIGER 대형성장
# 275750 KBSTAR 코스닥150선물인버스
# 256450 ARIRANG 심천차이넥스트(합성)
# 275280 KODEX MSCI모멘텀
# 241390 KBSTAR V&S셀렉트밸류채권혼합
# 139290 TIGER 200 경기소비재
# 290130 KBSTAR ESG사회책임투자
# 166400 TIGER 200커버드콜5%OTM
# 192720 파워 고배당저변동성
# 267440 KBSTAR 미국장기국채선물(H)
# 302210 TIGER 중장기국채선물인버스2X
# 292580 TIGER 일본엔선물인버스
# 238670 ARIRANG 스마트베타Quality채권혼합
# 170350 TIGER 베타플러스
# 139220 TIGER 200 건설
# 252720 KBSTAR 모멘텀밸류
# 287330 KBSTAR 200생활소비재
# 342600 KBSTAR KRX국채선물3년10년스티프너2X
# 176710 파워 중기국고채
# 098560 TIGER 방송통신
# 342500 KBSTAR KRX국채선물3년10년스티프너
# 292120 TIGER 중소형
# 102960 KODEX 기계장비
# 301410 ARIRANG 코스닥150선물인버스
# 307610 TIGER KRX300레버리지
# 291680 KBSTAR 차이나H선물인버스(H)
# 211260 KINDEX 배당성장
# 342610 KBSTAR KRX국채선물3년10년플래트너
# 145670 KINDEX 인버스
# 322120 KINDEX 스마트퀄리티
# 342620 KBSTAR KRX국채선물3년10년플래트너2X
# 266390 KODEX 경기소비재
# 213630 ARIRANG 미국다우존스고배당주(합성 H)
# 260270 KOSEF 저PBR가중
# 261270 KODEX 미국달러선물인버스
# 291130 KINDEX 멕시코MSCI(합성)
# 314700 HANARO 농업융복합산업
# 244660 KODEX 퀄리티Plus
# 269530 ARIRANG S&P글로벌인프라
# 261140 TIGER 우선주
# 315480 KBSTAR 200커뮤니케이션서비스
# 253240 KOSEF 200선물인버스
# 226380 KINDEX 한류
# 289260 TIGER MSCI KOREA ESG리더스
# 291620 KOSEF 코스닥150선물인버스
# 292590 TIGER 일본엔선물인버스2X
# 275300 KODEX MSCI퀄리티
# 289250 TIGER MSCI KOREA ESG유니버설
# 252000 TIGER 200동일가중
# 301440 ARIRANG 코스피중형주
# 306530 HANARO 코스닥150선물레버리지
# 291610 KOSEF 코스닥150선물
# 213610 KODEX 삼성그룹밸류
# 292140 TIGER 중소형가치
# 195970 ARIRANG 선진국MSCI(합성 H)
# 354350 HANARO 글로벌럭셔리S&P(합성)
# 307520 TIGER 지주회사
# 292770 KODEX 국채선물3년인버스
# 290080 KBSTAR 200고배당커버드콜ATM
# 253280 KBSTAR 헬스케어
# 261920 KINDEX 필리핀MSCI(합성)
# 299080 KINDEX 국채선물3년인버스
# 292110 TIGER 대형가치
# 226980 KODEX 200 중소형
# 307020 KBSTAR KRX300선물인버스
# 269370 TIGER S&P글로벌인프라(합성)
# 309170 ARIRANG KRX300IT
# 301400 ARIRANG 코스닥150
# 299070 KINDEX 국채선물10년인버스
# 291660 KODEX China H선물인버스(H)
# 244670 KODEX 밸류Plus
# 228800 TIGER 여행레저
# 291890 KODEX MSCI EM선물(H)
# 247800 KODEX 턴어라운드투자
# 091220 TIGER 은행
# 263190 ARIRANG 단기우량채권
# 252410 KBSTAR 200선물인버스
# 227560 TIGER 200 생활소비재
# 140710 KODEX 운송
# 247790 KODEX 성장투자
# 304670 KODEX 미국채울트라30년선물인버스(H)
# 300290 KBSTAR 중소형모멘텀밸류
# 321410 KODEX 멀티에셋하이인컴(H)
# 295020 KBSTAR 국채선물10년인버스
# 267450 KBSTAR 미국장기국채선물인버스(H)
# 140570 KBSTAR 수출주
# 247780 KODEX 가치투자
# 300610 TIGER K게임
# 278420 ARIRANG ESG우수기업
# 280940 KODEX 골드선물인버스(H)
# 300280 KBSTAR 중소형모멘텀로우볼
# 326230 KBSTAR 내수주플러스
# 306960 KODEX KRX300선물인버스
# 307620 TIGER KRX300선물인버스
# 285010 KBSTAR 200중공업
# 139310 TIGER 금속선물(H)
# 284990 KBSTAR 200에너지화학
# 227550 TIGER 200 산업재
# 140580 KBSTAR 우량업종
# 267500 KBSTAR 미국장기국채선물인버스2X(합성 H)
# 287320 KBSTAR 200산업재
# 217770 TIGER 원유선물인버스(H)
# 139240 TIGER 200 철강소재
# 285020 KBSTAR 200철강소재
# 334700 KBSTAR 팔라듐선물인버스(H)
# 295820 ARIRANG 200동일가중
# 287300 KBSTAR 200건설
# 284980 KBSTAR 200금융
# 287310 KBSTAR 200경기소비재
# 266140 TIGER 지속배당

# %%
# 앞의 과정을 urllib 표준 라이브러리 말고 requests 라이브러리를 사용하면 훨씬 간단하게 된다.
# 위의 과정을 한줄로 요약할 수 있다.

import requests
json_data = json.loads(requests.get(url).text)

# json_noramlize를 사용하면 json 형태의 딕셔너리 데이터를 바로 데이터프레임 형태로 저장할 수 있다.
df = json_normalize(json_data['result']['etfItemList'])

# 데이터프레임 출력 및 확인
print(df.head(10))
# Out:
# itemcode  etfTabCode              itemname  nowVal risefall  changeVal  \
# 0   069500           1             KODEX 200   31325        5       -390
# 1   102110           1             TIGER 200   31340        5       -380
# 2   252670           3      KODEX 200선물인버스2X    4140        2         90
# 3   122630           3            KODEX 레버리지   15020        5       -345
# 4   153130           6            KODEX 단기채권  102455        5         -5
# 5   273130           6  KODEX 종합채권(AA-이상)액티브  110395        2        220
# 6   102780           2            KODEX 삼성그룹    7650        5        -85
# 7   157450           6           TIGER 단기통안채  100655        3          0
# 8   114800           3             KODEX 인버스    5445        2         60
# 9   278530           1           KODEX 200TR   10050        5       -110
#
#    changeRate       nav  threeMonthEarnRate      quant  amonut  marketSum
# 0       -1.23   31424.0              9.2791    5170204  162520      50167
# 1       -1.20   31424.0              9.3529     766875   24093      26388
# 2        2.22    4173.0            -20.1971  149233144  616480      23896
# 3       -2.25   15043.0             17.0666   40227032  606777      22740
# 4        0.00  102459.0              0.0976      11487    1176      17611
# 5        0.20  110358.0              0.0817       5061     558      13435
# 6       -1.10    7680.0              6.0315     155009    1185      13051
# 7        0.00  100654.0              0.0994        980      98      12028
# 8        1.11    5466.0            -10.1752   32076381  174504      11941
# 9       -1.08   10072.0              9.2473      56613     570      11578

# %% [markdown]
# ## 주가데이터 패키지를 이용하여 가져오기
#
# - 위에서 네이버 차트의 주가데이터를 가져올 수 있었다 (네이버는 상당히 많은 양의 과거자료를 포함하고 있음)
#
# - 하지만 한국주식 한정이라는 점도 있고 무엇보다 사용하기 편하지 않다.
#
# - 이번에는 남들이 만들어 놓은 패키지들을 활용해서 주가 데이터를 가져와보자
#
#     - FinanceDataReader 사용
#
#     - pandas_datareadr 사용

# %%
import FinanceDataReader as fdr 

# 삼성전자 5년간 가격데이터. 종목코드, 시작일, 종료일 순. 종료일 없으면 최근것 까지
ss_df = fdr.DataReader('005930', '2015-01-01', '2019-12-31')

# 여기서 종가 Close는 수정주가이다. financedataread는 investing에서 자료를 가져오는데 인베스팅이 수정주가를 기준으로 종가를 표시한다.
print(ss_df)
# Out:
# Open   High    Low  Close    Volume    Change
# Date
# 2015-01-02  26799  26799  26540  26600    175499  0.002261
# 2015-01-05  26720  26720  26260  26660    202790  0.002256
# 2015-01-06  26300  26340  25760  25900    304710 -0.028507
# 2015-01-07  25880  26220  25640  26140    286455  0.009266
# 2015-01-08  26780  26780  26199  26280    289552  0.005356
# ...           ...    ...    ...    ...       ...       ...
# 2019-12-23  56100  56400  55100  55500   9839252 -0.008929
# 2019-12-24  55600  55700  54800  55000  11868463 -0.009009
# 2019-12-26  54700  55400  54400  55400   9645034  0.007273
# 2019-12-27  55700  56900  55500  56500  12313056  0.019856
# 2019-12-30  56200  56600  55700  55800   8356767 -0.012389
#
# [1227 rows x 6 columns]

# %%
# padas 에서 제공하는 data_reader 모듈을 이용해서도 주가 데이터를 가져올 수 있다.
# 구글, 야후, fred 등등이 있는데 야후 파이낸스 데이터를 가져와보다.
import pandas as pd
import pandas_datareader.data as pdr

# 야후 파이낸스를 판다스에서 중단했어서 그 기능을 사용하기 위해 불러올 모듈
import yfinance as yf
yf.pdr_override()

# 종목코드, 시작일, 종료일 순. 종료일 없으면 최근것 까지
ss_df = pdr.get_data_yahoo('005930.KS', '2000-01-04')  

# OHLCV와 수정주가도 따로 표시됨을 확인할 수 있음.
print(ss_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2000-01-04   6000.0   6110.0   5660.0   6110.0      0.090599  74195000
# 2000-01-05   5800.0   6060.0   5520.0   5580.0      0.082740  74680000
# 2000-01-06   5750.0   5780.0   5580.0   5620.0      0.083333  54390000
# 2000-01-07   5560.0   5670.0   5360.0   5540.0      0.082147  40305000
# 2000-01-10   5600.0   5770.0   5580.0   5770.0      0.085558  46880000
# ...             ...      ...      ...      ...           ...       ...
# 2020-09-03  55600.0  56700.0  55500.0  56400.0  56400.000000  28384920
# 2020-09-04  55200.0  55800.0  55100.0  55600.0  55600.000000  22139109
# 2020-09-07  56100.0  57300.0  55800.0  56500.0  56500.000000  18685880
# 2020-09-08  57400.0  58700.0  57200.0  58700.0  58700.000000  31517520
# 2020-09-09  58200.0  59300.0  57800.0  58400.0  58400.000000  30031011
#
# [5194 rows x 6 columns]
