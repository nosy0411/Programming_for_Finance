# %% [markdown]
# # week1 과제

# %%
from IPython.display import Image

# 과제 1 문제
Image("img/week1_1.png")

# %% [markdown]
# ## 과제 1 해답

# %%
# 과제 1 해답

# %%
# 과제 2,3 문제
Image("img/week1_2.png")

# %%
# 과제2,3 해답

# %%
# 과제 4 문제
Image("img/week1_4.png")

# %%
# 과제4 해답

# %%
# 과제 5 문제
Image("img/week1_5.png")

# %%
# 과제 5 해답

# %%
# 과제 6 문제
Image("img/week1_6.png")

# %%
# 과제 6 해답

# %%
# 과제 7 문제
Image("img/week1_7.png")

# %%
# 과제 7 해답
